# %% [markdown]
# # Purpose
# Generate a visual of the counties that have been visited.

# %% [markdown]
# # Setup
# ## Import - Packages

# %%
# ---------------------------------------------------------------------------- #
# GENERAL #

# ---------------------------------------------------------------------------- #
# ANALYSIS #

# ---------------------------------------------------------------------------- #
# SPATIAL #

# ---------------------------------------------------------------------------- #
# VISUALIZATION

# ---------------------------------------------------------------------------- #
# LOCAL #
from tracking_counties.main import tracking_counties

# %% [markdown]
# # Execute

# %%
tracking_counties(
    print_plot = True, 
    save_plot = True
)
# Out:
# /Users/evancanfield/.pyenv/versions/3.11.5/envs/.tracking_counties_3115/lib/python3.11/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 10 x 6 in image.
# /Users/evancanfield/.pyenv/versions/3.11.5/envs/.tracking_counties_3115/lib/python3.11/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: /Users/evancanfield/Documents/Projects/trackingcounties/data/plots/contiguous.png
# /Users/evancanfield/.pyenv/versions/3.11.5/envs/.tracking_counties_3115/lib/python3.11/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 7 x 6 in image.
# /Users/evancanfield/.pyenv/versions/3.11.5/envs/.tracking_counties_3115/lib/python3.11/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: /Users/evancanfield/Documents/Projects/trackingcounties/data/plots/alaska.png
# /Users/evancanfield/.pyenv/versions/3.11.5/envs/.tracking_counties_3115/lib/python3.11/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 6 x 6 in image.
# /Users/evancanfield/.pyenv/versions/3.11.5/envs/.tracking_counties_3115/lib/python3.11/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: /Users/evancanfield/Documents/Projects/trackingcounties/data/plots/hawaii.png
